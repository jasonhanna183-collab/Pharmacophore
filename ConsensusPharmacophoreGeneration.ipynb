# %% [markdown]
# ## 🧬 What Pharmit Does When You Upload an .sdf with Multiple Molecules
#
# When you click “Load Features” (or upload an .sdf or .mol2 file with multiple molecules), Pharmit only uses the first molecule in the file to:
#
# Generate the pharmacophore
#
# Display the 3D structure
#
# Create shape-based searches
#
# The other molecules are ignored.
#
# ## 💡 Why This Happens
#
# Pharmit is designed for interactive pharmacophore-based virtual screening, not multi-ligand consensus modeling.
# Its workflow assumes:
#
# One ligand → generate pharmacophore → search databases for similar molecules.
#
# So even if your .sdf has 1000 entries, Pharmit’s backend loads only the first conformer / first molecule record to:
#
# Calculate hydrogen bond donors/acceptors, hydrophobics, aromatics, etc.
#
# Display the molecular surface and features.
#
# There’s currently no built-in function in Pharmit to merge or average features across multiple hits.
#
# ### INSTEAD - First Generate consensus pharmacophore model with RDKIT:
#
# this version of the RDKit script will take an .sdf file with many molecules (e.g. 1000 hits) and build a consensus pharmacophore that combines the common features across all of them.
#
# It automatically:
#
# Embeds + aligns all molecules in 3D
#
# Detects features (H-bond donors, acceptors, aromatics, hydrophobics)
#
# Clusters nearby features spatially to merge them into consensus points
#
# Outputs a Pharmit-compatible .phar file
#
# ## 🧬 RDKit Consensus Pharmacophore Builder (for multi-hit .sdf)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, rdMolAlign, ChemicalFeatures
from rdkit import RDConfig
import numpy as np
from sklearn.cluster import DBSCAN
import json, os

# === Input / Output ===
input_sdf = "VinaResults_9ety_apo_hit_ligands.sdf"
output_phar = "consensus.phar"

# === Load molecules ===
mols = [m for m in Chem.SDMolSupplier(input_sdf) if m is not None]
print(f"Loaded {len(mols)} molecules")

# === Generate 3D conformers (if missing) ===
for m in mols:
    if not m.GetNumConformers():
        m = Chem.AddHs(m)
        AllChem.EmbedMolecule(m, AllChem.ETKDG())
        AllChem.UFFOptimizeMolecule(m)

# === Align all molecules to the first ===
ref = mols[0]
for m in mols[1:]:
    try:
        rdMolAlign.AlignMol(m, ref)
    except:
        pass

# === Set up RDKit feature factory ===
fdefName = os.path.join(RDConfig.RDDataDir, 'BaseFeatures.fdef')
factory = ChemicalFeatures.BuildFeatureFactory(fdefName)

# === Collect all feature positions and types ===
positions, families = [], []
for m in mols:
    feats = factory.GetFeaturesForMol(m)
    for f in feats:
        fam = f.GetFamily()
        pos = np.array(f.GetPos())
        positions.append(pos)
        families.append(fam)

positions = np.array(positions)
families = np.array(families)

# === Cluster features of same type (DBSCAN groups close ones) ===
consensus_features = []
eps = 1.5  # Å radius for clustering
min_samples = max(2, len(mols)//20)  # feature must appear in at least 5% of molecules

for fam in np.unique(families):
    fam_positions = positions[families == fam]
    if len(fam_positions) == 0:
        continue
    clustering = DBSCAN(eps=eps, min_samples=min_samples).fit(fam_positions)
    labels = clustering.labels_

    for label in set(labels):
        if label == -1:
            continue  # ignore outliers
        cluster_points = fam_positions[labels == label]
        centroid = np.mean(cluster_points, axis=0)
        consensus_features.append({
            "family": fam,
            "x": float(centroid[0]),
            "y": float(centroid[1]),
            "z": float(centroid[2]),
            "count": int(len(cluster_points)),
            "radius": round(eps, 2)
        })

print(f"✅ Found {len(consensus_features)} consensus pharmacophore points")

# === Convert to Pharmit-compatible JSON ===
pharmit_format = {
    "points": [
        {
            "enabled": True,
            "shape": f["family"],
            "radius": f["radius"],
            "location": {
                "x": f["x"],
                "y": f["y"],
                "z": f["z"]
            }
        }
        for f in consensus_features
    ],
    "excluded": []
}

output_json = output_phar.replace(".phar", ".json")
with open(output_json, "w") as f:
    json.dump(pharmit_format, f, indent=2)

print(f"✅ Saved Pharmit-compatible pharmacophore to {output_json}")
# Out:
# [16:27:32] Explicit valence for atom # 8 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 1897
# [16:27:32] ERROR: Explicit valence for atom # 8 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 2266
# [16:27:32] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 3482
# [16:27:32] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 3574
# [16:27:32] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 3675
# [16:27:32] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 4900
# [16:27:32] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 3 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 6855
# [16:27:32] ERROR: Explicit valence for atom # 3 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 16 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 8846
# [16:27:32] ERROR: Explicit valence for atom # 16 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 5 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 9384
# [16:27:32] ERROR: Explicit valence for atom # 5 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 16 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 9478
# [16:27:32] ERROR: Explicit valence for atom # 16 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 13888
# [16:27:32] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 21278
# [16:27:32] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 23147
# [16:27:32] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 29484
# [16:27:32] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 14 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 38591
# [16:27:32] ERROR: Explicit valence for atom # 14 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 54989
# [16:27:32] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 70030
# [16:27:32] ERROR: Explicit valence for atom # 0 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 7 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 80433
# [16:27:32] ERROR: Explicit valence for atom # 7 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 8 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 80527
# [16:27:32] ERROR: Explicit valence for atom # 8 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 80623
# [16:27:32] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 80719
# [16:27:32] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 80815
# [16:27:32] ERROR: Explicit valence for atom # 6 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 8 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 80920
# [16:27:32] ERROR: Explicit valence for atom # 8 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 7 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 81023
# [16:27:32] ERROR: Explicit valence for atom # 7 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 10 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 87017
# [16:27:32] ERROR: Explicit valence for atom # 10 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 0 C, 5, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 104209
# [16:27:32] ERROR: Explicit valence for atom # 0 C, 5, is greater than permitted
# [16:27:32] Explicit valence for atom # 9 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 111892
# [16:27:32] ERROR: Explicit valence for atom # 9 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 111987
# [16:27:32] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 114525
# [16:27:32] ERROR: Explicit valence for atom # 2 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 1 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 117049
# [16:27:32] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [16:27:32] Explicit valence for atom # 1 N, 4, is greater than permitted
# [16:27:32] ERROR: Could not sanitize molecule ending on line 117230
# [16:27:32] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# Loaded 1300 molecules
# ✅ Found 11 consensus pharmacophore points
# ✅ Saved Pharmit-compatible pharmacophore to consensus.json

# %% [markdown]
# ## Using the CONPHAR library - https://doi.org/10.1021/acs.jcim.3c01439

# %%
import conphar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import conphar
#
# File c:\Users\Jason\Docking\env\lib\site-packages\conphar\__init__.py:10
#       6 __author__  = "https://github.com/AngelRuizMoreno"
#       9 from .Structures import *
# ---> 10 from .Pharmacophores import *
#      12 print("ConPhar tools imported successfully")
#
# File c:\Users\Jason\Docking\env\lib\site-packages\conphar\Pharmacophores.py:279
#     274     with open(out_file, 'w') as file:
#     275         json.dump(data, file, indent=4)
# --> 279 def compute_concensus_pharmacophore (table:pd.DataFrame, save_data_per_descriptor:bool=True, out_folder:str='.', h_dist:float=1.5,cmap_plots:str='binary_r', feature_size:dict|None=None, method:str='complete'):
#     280     """
#     281     Computes the concensus pharmacophore from a table of 3D coordinates and features of molecular descriptors.
#     282
#    (...)
#     316     2   Donor_Acceptor        1 -0.063333 -0.063333 -0.063333     0.5      2       3  0.333333
#     317     """
#     319     def __compute_cluster(table:pd.DataFrame, method='complete'):
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'
